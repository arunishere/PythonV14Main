# %% [markdown]
# ## Data Analytics with Python

# %%
import pandas as pd

# %%
orange_data = pd.read_csv('Orange Quality Data.csv')

# %%
for i in orange_data.columns:
    print(i)
# Out:
# Size (cm)
# Weight (g)
# Brix (Sweetness)
# pH (Acidity)
# Softness (1-5)
# HarvestTime (days)
# Ripeness (1-5)
# Color
# Variety
# Blemishes (Y/N)
# Quality (1-5)

# %%
orange_data.shape
# Out:
# (241, 11)

# %%
orange_data.head(10)
# Out:
#    Size (cm)  Weight (g)  Brix (Sweetness)  pH (Acidity)  Softness (1-5)  \
# 0        7.5         180              12.0           3.2             2.0
# 1        8.2         220              10.5           3.4             3.0
# 2        6.8         150              14.0           3.0             1.0
# 3        9.0         250               8.5           3.8             4.0
# 4        8.5         210              11.5           3.3             2.5
# 5        6.7         126               9.1           3.0             2.0
# 6        7.2         160               9.0           3.5             3.5
# 7        6.5         130              13.5           2.8             1.5
# 8        8.8         240               7.5           4.0             5.0
# 9        7.8         190              12.0           3.1             2.0
#
#    HarvestTime (days)  Ripeness (1-5)          Color           Variety  \
# 0                  10             4.0         Orange          Valencia
# ...

# %%
orange_data.tail(10)
# Out:
#      Size (cm)  Weight (g)  Brix (Sweetness)  pH (Acidity)  Softness (1-5)  \
# 231        9.5         131               6.1           3.3             5.0
# 232        6.1         273               8.3           4.3             1.0
# 233        8.2         249              12.8           3.8             3.0
# 234        8.6         251              11.5           3.8             5.0
# 235        8.5         130               8.1           3.6             3.0
# 236        8.0         194              10.9           3.6             5.0
# 237        7.4         275               8.5           3.5             5.0
# 238        7.5         196              15.7           3.0             3.0
# 239        7.2         251               9.8           4.3             3.0
# 240        7.3         282              10.5           2.9             4.0
#
#      HarvestTime (days)  Ripeness (1-5)         Color            Variety  \
# ...

# %%
orange_data.sample(10)
# Out:
#      Size (cm)  Weight (g)  Brix (Sweetness)  pH (Acidity)  Softness (1-5)  \
# 213        6.9         146               8.7           3.4             5.0
# 156        6.4         298              15.2           3.0             2.0
# 170        7.2         288               6.9           3.6             2.0
# 214        6.1         233              10.9           3.0             5.0
# 97         8.5         220               9.0           3.6             3.5
# 38         8.0         200              11.5           3.4             3.0
# 162        6.6         141              13.9           3.2             4.0
# 25         8.4         215               8.5           3.8             4.0
# 197        8.3         261              13.2           3.8             3.0
# 36         7.3         165              10.0           3.3             2.5
#
#      HarvestTime (days)  Ripeness (1-5)         Color               Variety  \
# ...

# %%
orange_data.sample(frac=0.02)
# Out:
#      Size (cm)  Weight (g)  Brix (Sweetness)  pH (Acidity)  Softness (1-5)  \
# 199        9.6         288               6.6           2.8             2.0
# 215        8.1         248               7.4           3.0             5.0
# 49         7.2         160              11.5           3.2             2.0
# 228        7.6         189              11.5           3.2             2.0
# 8          8.8         240               7.5           4.0             5.0
#
#      HarvestTime (days)  Ripeness (1-5)         Color           Variety  \
# 199                  19             2.0  Light Orange  Washington Navel
# 215                  18             2.0  Light Orange         Cara Cara
# 49                    8             4.5   Deep Orange            Temple
# 228                  12             4.0    Orange-Red          Ambiance
# 8                    18             3.0   Deep Orange      Moro (Blood)
#
#     Blemishes (Y/N)  Quality (1-5)
# 199               N            1.0
# ...

# %%
orange_data.columns
# Out:
# Index(['Size (cm)', 'Weight (g)', 'Brix (Sweetness)', 'pH (Acidity)',
#        'Softness (1-5)', 'HarvestTime (days)', 'Ripeness (1-5)', 'Color',
#        'Variety', 'Blemishes (Y/N)', 'Quality (1-5)'],
#       dtype='object')

# %%
#Only Specific Columns

cols = ['Size (cm)', 'Weight (g)', 'Brix (Sweetness)', 'Color']
orange_2 = orange_data[cols]

# %%
orange_data.head(5)
# Out:
#    Size (cm)  Weight (g)  Brix (Sweetness)  pH (Acidity)  Softness (1-5)  \
# 0        7.5         180              12.0           3.2             2.0
# 1        8.2         220              10.5           3.4             3.0
# 2        6.8         150              14.0           3.0             1.0
# 3        9.0         250               8.5           3.8             4.0
# 4        8.5         210              11.5           3.3             2.5
#
#    HarvestTime (days)  Ripeness (1-5)         Color       Variety  \
# 0                  10             4.0        Orange      Valencia
# 1                  14             4.5   Deep Orange         Navel
# 2                   7             5.0  Light Orange     Cara Cara
# 3                  21             3.5    Orange-Red  Blood Orange
# 4                  12             5.0        Orange        Hamlin
#
#   Blemishes (Y/N)  Quality (1-5)
# 0               N            4.0
# 1               N            4.5
# ...

# %%
orange_data['Color'].unique()
# Out:
# array(['Orange', 'Deep Orange', 'Light Orange', 'Orange-Red',
#        'Yellow-Orange'], dtype=object)

# %%
orange_data['Color'].nunique()
# Out:
# 5

# %%
# import numpy as np
# v = pd.Series([1,1,1,1,1,2,3,4])
# print(v.mode())
# Out:
# 0    1
# dtype: int64

# %%
['L', 'M', 'XXL', 'XL', 'S']

orange_data['Size (cm)'].mean()
# Out:
# 7.844813278008298

# %%
orange_data.describe()
# Out:
#         Size (cm)  Weight (g)  Brix (Sweetness)  pH (Acidity)  Softness (1-5)  \
# count  241.000000  241.000000        241.000000    241.000000      241.000000
# mean     7.844813  205.128631         10.907884      3.473900        3.072614
# std      1.086002   56.461012          2.760446      0.421007        1.323630
# min      6.000000  100.000000          5.500000      2.800000        1.000000
# 25%      6.900000  155.000000          8.500000      3.200000        2.000000
# 50%      7.800000  205.000000         11.000000      3.400000        3.000000
# 75%      8.700000  252.000000         13.400000      3.800000        4.000000
# max     10.000000  300.000000         16.000000      4.400000        5.000000
#
#        HarvestTime (days)  Ripeness (1-5)  Quality (1-5)
# count          241.000000      241.000000     241.000000
# mean            15.344398        3.599585       3.817427
# std              5.323852        1.205214       1.014410
# ...

# %%
orange_data[(orange_data['Color'] == 'Orange')]
# Out:
#      Size (cm)  Weight (g)  Brix (Sweetness)  pH (Acidity)  Softness (1-5)  \
# 0          7.5         180              12.0          3.20             2.0
# 4          8.5         210              11.5          3.30             2.5
# 5          6.7         126               9.1          3.00             2.0
# 9          7.8         190              12.0          3.10             2.0
# 12         8.0         200              10.0          3.50             3.0
# 16         8.7         230               8.0          3.90             3.5
# 22         7.6         180               9.0          3.30             3.0
# 24         7.9         190              10.5          3.10             2.5
# 30         8.3         220              11.0          3.30             3.0
# 35         8.6         225               9.5          3.60             3.0
# 38         8.0         200              11.5          3.40             3.0
# ...

# %%
orange_data[(orange_data['Color'] == 'Orange')  &  (orange_data['Variety'] == 'Navel') & (orange_data['Blemishes (Y/N)'] == 'N')]
# Out:
#      Size (cm)  Weight (g)  Brix (Sweetness)  pH (Acidity)  Softness (1-5)  \
# 5          6.7         126               9.1          3.00             2.0
# 100        7.7         192              12.6          3.43             4.0
# 132        7.9         155              12.4          3.58             1.0
# 205        7.5         138               7.0          4.10             1.0
#
#      HarvestTime (days)  Ripeness (1-5)   Color Variety Blemishes (Y/N)  \
# 5                    25             2.0  Orange   Navel               N
# 100                  21             3.0  Orange   Navel               N
# 132                  15             5.0  Orange   Navel               N
# 205                  20             3.0  Orange   Navel               N
#
#      Quality (1-5)
# 5              1.0
# 100            3.0
# 132            5.0
# 205            2.0

# %%
orange_imp = orange_data[
            (orange_data['Color'] == 'Orange')  &  
            (orange_data['Variety'] == 'Navel') & 
            (orange_data['Blemishes (Y/N)'] == 'N')
            ]

# %%
orange_imp
# Out:
#      Size (cm)  Weight (g)  Brix (Sweetness)  pH (Acidity)  Softness (1-5)  \
# 5          6.7         126               9.1          3.00             2.0
# 100        7.7         192              12.6          3.43             4.0
# 132        7.9         155              12.4          3.58             1.0
# 205        7.5         138               7.0          4.10             1.0
#
#      HarvestTime (days)  Ripeness (1-5)   Color Variety Blemishes (Y/N)  \
# 5                    25             2.0  Orange   Navel               N
# 100                  21             3.0  Orange   Navel               N
# 132                  15             5.0  Orange   Navel               N
# 205                  20             3.0  Orange   Navel               N
#
#      Quality (1-5)
# 5              1.0
# 100            3.0
# 132            5.0
# 205            2.0

# %%
orange_data[(orange_data['Variety'] == 'Navel') | (orange_data['Variety'] == 'Valencia')]
# Out:
#      Size (cm)  Weight (g)  Brix (Sweetness)  pH (Acidity)  Softness (1-5)  \
# 0          7.5         180              12.0          3.20             2.0
# 1          8.2         220              10.5          3.40             3.0
# 5          6.7         126               9.1          3.00             2.0
# 11         7.8         183              14.8          3.70             2.0
# 100        7.7         192              12.6          3.43             4.0
# 102        8.9         118               8.1          3.32             5.0
# 110        9.9         152               6.4          3.33             4.0
# 111        6.9         270               7.4          3.85             2.0
# 115        6.1         279              14.1          3.90             4.0
# 132        7.9         155              12.4          3.58             1.0
# 133        6.7         198              10.6          2.80             3.0
# ...

# %%
#Filtering with multiple values in the same column

variety_filter = ['Navel', 'Valencia', 'Star Ruby'] 
orange_data[(orange_data['Variety'].isin(variety_filter))]
# Out:
#      Size (cm)  Weight (g)  Brix (Sweetness)  pH (Acidity)  Softness (1-5)  \
# 0          7.5         180              12.0          3.20             2.0
# 1          8.2         220              10.5          3.40             3.0
# 5          6.7         126               9.1          3.00             2.0
# 11         7.8         183              14.8          3.70             2.0
# 14         9.2         260               9.5          3.70             4.5
# 40         9.2         260              10.5          3.20             4.0
# 56         9.1         255              11.0          3.20             4.0
# 74         9.3         270               7.0          4.10             4.5
# 100        7.7         192              12.6          3.43             4.0
# 102        8.9         118               8.1          3.32             5.0
# 108        8.9         269               6.7          3.67             4.0
# ...

# %%
orange_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241 entries, 0 to 240
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Size (cm)           241 non-null    float64
#  1   Weight (g)          241 non-null    int64
#  2   Brix (Sweetness)    241 non-null    float64
#  3   pH (Acidity)        241 non-null    float64
#  4   Softness (1-5)      241 non-null    float64
#  5   HarvestTime (days)  241 non-null    int64
#  6   Ripeness (1-5)      241 non-null    float64
#  7   Color               241 non-null    object
#  8   Variety             241 non-null    object
#  9   Blemishes (Y/N)     241 non-null    object
#  10  Quality (1-5)       241 non-null    float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 20.8+ KB

# %%
orange_data.sort_values(by='Size (cm)', ascending=False)
# Out:
#      Size (cm)  Weight (g)  Brix (Sweetness)  pH (Acidity)  Softness (1-5)  \
# 20        10.0         300               7.0          4.10             5.0
# 53         9.9         290               5.5          4.40             5.0
# 207        9.9         169              12.8          3.70             1.0
# 110        9.9         152               6.4          3.33             4.0
# 23         9.8         280               6.5          4.30             5.0
# ..         ...         ...               ...           ...             ...
# 214        6.1         233              10.9          3.00             5.0
# 180        6.1         198               9.0          3.10             4.0
# 51         6.1         105              14.0          2.90             1.0
# 139        6.0         157               9.2          3.85             1.0
# 71         6.0         100              14.5          2.80             1.0
#
# ...

# %%
orange_data_2 = orange_data.copy()

# %%
# 1: Columns 
# 0: Rows

orange_data_2.drop(['Softness (1-5)', 'HarvestTime (days)'], axis=1, inplace=True)

# %%
orange_data_2
# Out:
#      Size (cm)  Weight (g)  Brix (Sweetness)  pH (Acidity)  Ripeness (1-5)  \
# 0          7.5         180              12.0           3.2             4.0
# 1          8.2         220              10.5           3.4             4.5
# 2          6.8         150              14.0           3.0             5.0
# 3          9.0         250               8.5           3.8             3.5
# 4          8.5         210              11.5           3.3             5.0
# ..         ...         ...               ...           ...             ...
# 236        8.0         194              10.9           3.6             1.0
# 237        7.4         275               8.5           3.5             5.0
# 238        7.5         196              15.7           3.0             3.0
# 239        7.2         251               9.8           4.3             1.0
# 240        7.3         282              10.5           2.9             2.0
#
# ...

# %%
orange_data_2.drop([0,1], axis=0)
# Out:
#      Size (cm)  Weight (g)  Brix (Sweetness)  pH (Acidity)  Ripeness (1-5)  \
# 2          6.8         150              14.0           3.0             5.0
# 3          9.0         250               8.5           3.8             3.5
# 4          8.5         210              11.5           3.3             5.0
# 5          6.7         126               9.1           3.0             2.0
# 6          7.2         160               9.0           3.5             4.0
# ..         ...         ...               ...           ...             ...
# 236        8.0         194              10.9           3.6             1.0
# 237        7.4         275               8.5           3.5             5.0
# 238        7.5         196              15.7           3.0             3.0
# 239        7.2         251               9.8           4.3             1.0
# 240        7.3         282              10.5           2.9             2.0
#
# ...

# %%
orange_data_2.rename(
                    columns={'Size (cm)': 'Size', 
                             'Weight (g)': 'Weight'
                             }, inplace=True
                    )

# %%
orange_data_2
# Out:
#      Size  Weight  Brix (Sweetness)  pH (Acidity)  Ripeness (1-5)  \
# 0     7.5     180              12.0           3.2             4.0
# 1     8.2     220              10.5           3.4             4.5
# 2     6.8     150              14.0           3.0             5.0
# 3     9.0     250               8.5           3.8             3.5
# 4     8.5     210              11.5           3.3             5.0
# ..    ...     ...               ...           ...             ...
# 236   8.0     194              10.9           3.6             1.0
# 237   7.4     275               8.5           3.5             5.0
# 238   7.5     196              15.7           3.0             3.0
# 239   7.2     251               9.8           4.3             1.0
# 240   7.3     282              10.5           2.9             2.0
#
#             Color            Variety          Blemishes (Y/N)  Quality (1-5)
# 0          Orange           Valencia                        N            4.0
# ...

# %%
orange_data_2['Blemishes (Y/N)'].replace({'N': 'No',

                                          }, inplace=True)

# %%
orange_data_2
# Out:
#      Size  Weight  Brix (Sweetness)  pH (Acidity)  Ripeness (1-5)  \
# 0     7.5     180              12.0           3.2             4.0
# 1     8.2     220              10.5           3.4             4.5
# 2     6.8     150              14.0           3.0             5.0
# 3     9.0     250               8.5           3.8             3.5
# 4     8.5     210              11.5           3.3             5.0
# ..    ...     ...               ...           ...             ...
# 236   8.0     194              10.9           3.6             1.0
# 237   7.4     275               8.5           3.5             5.0
# 238   7.5     196              15.7           3.0             3.0
# 239   7.2     251               9.8           4.3             1.0
# 240   7.3     282              10.5           2.9             2.0
#
#             Color            Variety          Blemishes (Y/N)  Quality (1-5)
# 0          Orange           Valencia                       No            4.0
# ...

# %%
orange_data_2
# Out:
#      Size  Weight  Brix (Sweetness)  pH (Acidity)  Ripeness (1-5)  \
# 0     7.5     180              12.0           3.2             4.0
# 1     8.2     220              10.5           3.4             4.5
# 2     6.8     150              14.0           3.0             5.0
# 3     9.0     250               8.5           3.8             3.5
# 4     8.5     210              11.5           3.3             5.0
# ..    ...     ...               ...           ...             ...
# 236   8.0     194              10.9           3.6             1.0
# 237   7.4     275               8.5           3.5             5.0
# 238   7.5     196              15.7           3.0             3.0
# 239   7.2     251               9.8           4.3             1.0
# 240   7.3     282              10.5           2.9             2.0
#
#             Color            Variety          Blemishes (Y/N)  Quality (1-5)
# 0          Orange           Valencia                       No            4.0
# ...

# %%
#iloc[Row StartIndex : Row EndIndex, Col StartIndex : Col EndIndex]

orange_data_2.iloc[0:5, 2:4]
# Out:
#    Brix (Sweetness)  pH (Acidity)
# 0              12.0           3.2
# 1              10.5           3.4
# 2              14.0           3.0
# 3               8.5           3.8
# 4              11.5           3.3

# %%
orange_data_2.iloc[0:2, 5:7]
# Out:
# Empty DataFrame
# Columns: [Color, Variety]
# Index: []
#     Color   Variety
# 0  Orange  Valencia
#          Color   Variety
# 0       Orange  Valencia
# 1  Deep Orange     Navel
#           Color    Variety
# 0        Orange   Valencia
# 1   Deep Orange      Navel
# 2  Light Orange  Cara Cara
#           Color       Variety
# 0        Orange      Valencia
# 1   Deep Orange         Navel
# 2  Light Orange     Cara Cara
# 3    Orange-Red  Blood Orange
#           Color       Variety
# 0        Orange      Valencia
# 1   Deep Orange         Navel
# 2  Light Orange     Cara Cara
# 3    Orange-Red  Blood Orange
# 4        Orange        Hamlin
#           Color       Variety
# 0        Orange      Valencia
# 1   Deep Orange         Navel
# 2  Light Orange     Cara Cara
# 3    Orange-Red  Blood Orange
# 4        Orange        Hamlin
# 5        Orange         Navel
#            Color           Variety
# 0         Orange          Valencia
# 1    Deep Orange             Navel
# ...

# %%
orange_data_2.iloc[220: , 5:7]
# Out:
#             Color            Variety
# 220  Light Orange  Minneola (Hybrid)
# 221   Deep Orange  Minneola (Hybrid)
# 222  Light Orange         Clementine
# 223  Light Orange          Star Ruby
# 224   Deep Orange              Navel
# 225   Deep Orange           Ambiance
# 226   Deep Orange   Satsuma Mandarin
# 227  Light Orange       Moro (Blood)
# 228    Orange-Red           Ambiance
# 229  Light Orange          Cara Cara
# 230   Deep Orange       Moro (Blood)
# 231  Light Orange          Star Ruby
# 232        Orange              Navel
# 233   Deep Orange          Tangerine
# 234    Orange-Red         Clementine
# 235        Orange           Valencia
# 236    Orange-Red          Tangerine
# 237  Light Orange  Minneola (Hybrid)
# 238   Deep Orange             Temple
# 239  Light Orange       Moro (Blood)
# 240    Orange-Red              Jaffa

# %%
orange_data_2.loc[0:2, 'Brix (Sweetness)': 'pH (Acidity)']
# Out:
#    Brix (Sweetness)  pH (Acidity)
# 0              12.0           3.2
# 1              10.5           3.4
# 2              14.0           3.0

# %%
orange_data_2
# Out:
#      Size  Weight  Brix (Sweetness)  pH (Acidity)  Ripeness (1-5)  \
# 0     7.5     180              12.0           3.2             4.0
# 1     8.2     220              10.5           3.4             4.5
# 2     6.8     150              14.0           3.0             5.0
# 3     9.0     250               8.5           3.8             3.5
# 4     8.5     210              11.5           3.3             5.0
# ..    ...     ...               ...           ...             ...
# 236   8.0     194              10.9           3.6             1.0
# 237   7.4     275               8.5           3.5             5.0
# 238   7.5     196              15.7           3.0             3.0
# 239   7.2     251               9.8           4.3             1.0
# 240   7.3     282              10.5           2.9             2.0
#
#             Color            Variety          Blemishes (Y/N)  Quality (1-5)
# 0          Orange           Valencia                       No            4.0
# ...

# %%
orange_data_2.groupby(by=['Color'])['Color'].count()
# Out:
# Color
# Deep Orange      75
# Light Orange     64
# Orange           38
# Orange-Red       55
# Yellow-Orange     9
# Name: Color, dtype: int64

# %%
orange_data_2.groupby(by=['Variety'])['Weight'].mean()
# Out:
# Variety
# Ambiance                 198.000000
# Blood Orange             275.000000
# California Valencia      192.857143
# Cara Cara                227.095238
# Clementine               225.000000
# Clementine (Seedless)    130.000000
# Hamlin                   207.000000
# Honey Tangerine          185.571429
# Jaffa                    200.909091
# Midsweet (Hybrid)        227.000000
# Minneola (Hybrid)        192.000000
# Moro (Blood)             225.562500
# Murcott (Hybrid)         186.666667
# Navel                    205.875000
# Navel (Early Season)     192.500000
# Navel (Late Season)      213.333333
# Ortanique (Hybrid)       191.769231
# Satsuma Mandarin         200.307692
# Star Ruby                224.833333
# Tangelo (Hybrid)         160.000000
# Tangerine                176.000000
# Temple                   220.222222
# Valencia                 193.181818
# Washington Navel         185.071429
# Name: Weight, dtype: float64

# %%
orange_data_2.groupby(by=['Color'])['Size'].mean()
# Out:
# Color
# Deep Orange      7.830667
# Light Orange     7.510937
# Orange           7.907895
# Orange-Red       8.301818
# Yellow-Orange    7.277778
# Name: Size, dtype: float64

# %%
orange_data_3 = orange_data_2.iloc[220: , 5:7]

# %%
orange_data_3.to_excel('FileTest_2.xlsx')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 orange_data_3.to_excel('FileTest_2.xlsx')
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %% [markdown]
# ## Line Chart

# %%
df = pd.DataFrame()

df['Date'] = pd.date_range(start='2024-01-01', end='2024-12-30', freq='D')
df['Price'] = np.random.randint(320, 350, size=(365))
df['Price_2'] =  [2*x for x in range(0,365)]
df['Price_3'] =  [1.5*x for x in range(0,365)]
df['Price_4'] =  [1.75*x for x in range(0,365)]

df
# Out:
#           Date  Price  Price_2  Price_3  Price_4
# 0   2024-01-01    326        0      0.0     0.00
# 1   2024-01-02    334        2      1.5     1.75
# 2   2024-01-03    349        4      3.0     3.50
# 3   2024-01-04    347        6      4.5     5.25
# 4   2024-01-05    333        8      6.0     7.00
# ..         ...    ...      ...      ...      ...
# 360 2024-12-26    337      720    540.0   630.00
# 361 2024-12-27    338      722    541.5   631.75
# 362 2024-12-28    345      724    543.0   633.50
# 363 2024-12-29    336      726    544.5   635.25
# 364 2024-12-30    330      728    546.0   637.00
#
# [365 rows x 5 columns]

# %%
#Plotting a line.

plt.figure(figsize=(15,4))
plt.plot(df['Date'], df['Price_2'])
plt.plot(df['Date'], df['Price_3'])
plt.plot(df['Date'], df['Price_4'], linestyle='--')
plt.title('Sample Line Plotting')
plt.xlabel('Date')
plt.ylabel('Price($)')
plt.grid(True)
plt.legend(['2x', '1.5x', '1.75x'])
plt.show()

# %%
plt.figure(figsize=(15,4))
# plt.plot(df['Date'], df['Price_2'])
# plt.plot(df['Date'], df['Price_3'])
# plt.plot(df['Date'], df['Price_4'], linestyle='--')

sns.lineplot(x=df['Date'], y=df['Price_4'])
plt.title('Sample Line Plotting')
plt.xlabel('Date')
plt.ylabel('Price($)')
plt.grid(True)
plt.legend(['2x', '1.5x', '1.75x'])
plt.show()

# %%
x = np.linspace(0,10, 1000)
y = np.sin(x)
y1 = np.sin(2*x)
y3 = np.sin(4*x)
y4 = np.array([0.40 for x in range(0,1000)])

plt.figure(figsize=(15,4))
plt.plot(x,y)
# plt.plot(x,y1)
# plt.plot(x,y4,linestyle="--", color='r')
plt.plot(x,y3, linestyle="--", color='g')
plt.title('Sine Funtion')
plt.xlabel('Radians')
plt.ylabel('Sin(x)')
plt.grid(True)
plt.show()

# %%
x = np.linspace(0,10, 1000)
y = np.exp(x)

plt.figure(figsize=(6,4))
plt.plot(x,y)
plt.title('Exponential Funtion')
plt.xlabel('t')
plt.ylabel('e^t')
plt.grid(True)
plt.show()

# %%
x = np.arange(-100,100)
y = x ** 2

plt.figure(figsize=(6,4))
plt.plot(x,y)
plt.title('Power Funtion')
plt.xlabel('t')
plt.ylabel('x^2')
plt.grid(True)
plt.show()

# %%
x = np.arange(-100,100)
y = x ** 3

plt.figure(figsize=(6,4))
plt.plot(x,y)
plt.title('Power Funtion')
plt.xlabel('t')
plt.ylabel('x^2')
plt.grid(True)
plt.show()

# %%
# Simple Harmonic Oscillation

t = np.linspace(0, 10, 1000)
plt.figure(figsize=(14,4))
y = 1 * np.exp(-0.2 * t) * np.cos(2 * np.pi*t)
y2 = 1 * np.exp(-0.05 * t) * np.cos(2 * np.pi*t)
plt.plot(t, y, label='Damped Oscillation', color='crimson')
plt.plot(t, y2, label='Damped Oscillation', color='blue', linestyle='--')
plt.xlabel('Time (t)')
plt.ylabel('Displacement (y)')
plt.title('Damped Harmonic Motion')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ## Histogram

# %%
df = pd.read_csv('Orange Quality Data.csv')

# %%
df
# Out:
#      Size (cm)  Weight (g)  Brix (Sweetness)  pH (Acidity)  Softness (1-5)  \
# 0          7.5         180              12.0           3.2             2.0
# 1          8.2         220              10.5           3.4             3.0
# 2          6.8         150              14.0           3.0             1.0
# 3          9.0         250               8.5           3.8             4.0
# 4          8.5         210              11.5           3.3             2.5
# ..         ...         ...               ...           ...             ...
# 236        8.0         194              10.9           3.6             5.0
# 237        7.4         275               8.5           3.5             5.0
# 238        7.5         196              15.7           3.0             3.0
# 239        7.2         251               9.8           4.3             3.0
# 240        7.3         282              10.5           2.9             4.0
#
# ...

# %%
'''

Histograms - show distribution of values
x - axis always has numbers. 

'''

plt.figure(figsize=(6,4))
plt.hist(df['Size (cm)'], bins = 13)
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.hist(df['Quality (1-5)'], bins = 5)
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.histplot(df['Quality (1-5)'], bins = 10)
plt.show()

# %% [markdown]
# ## Bar Plot

# %%
df_group = df.groupby('Color')['Size (cm)'].mean()
df_group = pd.DataFrame(data=df_group)
df_group.reset_index(inplace=True)
df_group
# Out:
#            Color  Size (cm)
# 0    Deep Orange   7.830667
# 1   Light Orange   7.510937
# 2         Orange   7.907895
# 3     Orange-Red   8.301818
# 4  Yellow-Orange   7.277778

# %%
plt.bar(x=df_group['Color'], height=df_group['Size (cm)'])
plt.show()

# %%
df_group = df.groupby('Variety')['Size (cm)'].mean()
df_group = pd.DataFrame(data=df_group)
df_group.reset_index(inplace=True)
# df_group

plt.figure(figsize=(30,4))
sns.barplot(x=df_group['Variety'], y=df_group['Size (cm)'])
plt.show()

# %%
plt.figure(figsize=(5,10))
sns.barplot(y=df_group['Variety'], x=df_group['Size (cm)'])
plt.title('Average Size by Variety')
plt.show()

# %% [markdown]
# ## Box Plot

# %%
df.head(10)
# Out:
#    Size (cm)  Weight (g)  Brix (Sweetness)  pH (Acidity)  Softness (1-5)  \
# 0        7.5         180              12.0           3.2             2.0
# 1        8.2         220              10.5           3.4             3.0
# 2        6.8         150              14.0           3.0             1.0
# 3        9.0         250               8.5           3.8             4.0
# 4        8.5         210              11.5           3.3             2.5
# 5        6.7         126               9.1           3.0             2.0
# 6        7.2         160               9.0           3.5             3.5
# 7        6.5         130              13.5           2.8             1.5
# 8        8.8         240               7.5           4.0             5.0
# 9        7.8         190              12.0           3.1             2.0
#
#    HarvestTime (days)  Ripeness (1-5)          Color           Variety  \
# 0                  10             4.0         Orange          Valencia
# ...

# %%
df['Weight (g)'].median()
# Out:
# 205.0

# %%
sns.boxplot(y=df['Weight (g)'])
plt.show()

# %%
sns.boxplot(y=df['Brix (Sweetness)'])
plt.show()

# %%
sns.boxplot(x= df['Color'], y=df['Brix (Sweetness)'])
plt.show()

# %% [markdown]
# ## Voilin Plot

# %%
sns.violinplot(x= df['Color'], y=df['Brix (Sweetness)'])
plt.show()

# %%
sns.violinplot(x= df['Color'], y=df['pH (Acidity)'])
plt.show()

# %% [markdown]
# ## Scatter Plot

# %%
df.head(10)
# Out:
#    Size (cm)  Weight (g)  Brix (Sweetness)  pH (Acidity)  Softness (1-5)  \
# 0        7.5         180              12.0           3.2             2.0
# 1        8.2         220              10.5           3.4             3.0
# 2        6.8         150              14.0           3.0             1.0
# 3        9.0         250               8.5           3.8             4.0
# 4        8.5         210              11.5           3.3             2.5
# 5        6.7         126               9.1           3.0             2.0
# 6        7.2         160               9.0           3.5             3.5
# 7        6.5         130              13.5           2.8             1.5
# 8        8.8         240               7.5           4.0             5.0
# 9        7.8         190              12.0           3.1             2.0
#
#    HarvestTime (days)  Ripeness (1-5)          Color           Variety  \
# 0                  10             4.0         Orange          Valencia
# ...

# %%
sns.scatterplot(x=df['HarvestTime (days)'], y=df['Size (cm)'], hue=df['Color'])
plt.show()

# %%
sns.scatterplot(x=df['Weight (g)'], y=df['Size (cm)'])
plt.show()
